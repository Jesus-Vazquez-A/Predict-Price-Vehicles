# %% [markdown]
# ## **Load Libraires**

# %%
import pandas as pd
from intervals import IntervalFit
from histogram import histogram
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
mercedes = pd.read_csv('C:/Users/PC/Desktop/Car-Sales/data/cars_sales2.csv')
mercedes = mercedes.query("manufacturer == 'Mercedes-Benz'")

# %%
mercedes.model.unique()
# Out:
# array([' SLK', ' S Class', ' SL CLASS', ' G Class', ' GLE Class',
#        ' GLA Class', ' GLC Class', ' B Class', ' C Class', ' E Class',
#        ' GL Class', ' CLS Class', ' A Class', ' CLA Class', ' V Class',
#        ' CL Class', ' GLS Class', ' M Class', ' X-CLASS'], dtype=object)

# %%
mercedes.price.describe()
# Out:
# count     11183.000000
# mean      22954.972726
# std        9803.496582
# min        2140.000000
# 25%       16798.000000
# 50%       20800.000000
# 75%       26942.000000
# max      139995.000000
# Name: price, dtype: float64

# %%
_ = histogram(mercedes.price,"Price")

# %%
IntervalFit(mercedes.price).Lower_Interval()
# Out:
# Interval range STD 1.5: 8250.0
# Interval range STD 2: 3349.0
# Interval range STD 2.5: -1553.0
# Interval range STD 3.0: -6454.0
# Interval range STD 3.5: -11356.0
# Interval range STD 4: -16257.0

# %% [markdown]
# I find it convincing to use a lower range of £8k, as car manufacturer Mercedez Benz is not known for its low prices.

# %%
mercedes = mercedes.query("price > 8200")

# %%
IntervalFit(mercedes.price).Upper_Interval()
# Out:
# Interval range STD 1.5: 37676.0
# Interval range STD 2: 42521.0
# Interval range STD 2.5: 47366.0
# Interval range STD 3.0: 52211.0
# Interval range STD 3.5: 57056.0
# Interval range STD 4: 61901.0

# %%
mercedes.query("price > 62000").sort_values(by = "price",ascending = False).head(5)
# Out:
#           model  year   price transmission  mileage fuelType  engineSize  \
# 63023   G Class  2018  139995    Semi-Auto    13046   Petrol         4.0
# 57573   G Class  2019  139948    Automatic    12000   Petrol         4.0
# 62642   G Class  2018  135771    Semi-Auto    19000   Petrol         4.0
# 64113   G Class  2018  135124    Semi-Auto    18234   Petrol         4.0
# 59388   S Class  2019  109995    Semi-Auto     4688   Petrol         4.0
#
#         manufacturer
# 63023  Mercedes-Benz
# 57573  Mercedes-Benz
# 62642  Mercedes-Benz
# 64113  Mercedes-Benz
# 59388  Mercedes-Benz

# %%
s_class = mercedes.query("model == ' S Class'")
g_class =  mercedes.query("model == ' G Class'")

# %%
s_class.sort_values(by = "price",ascending = False).head(10)
# Out:
#           model  year   price transmission  mileage fuelType  engineSize  \
# 59388   S Class  2019  109995    Semi-Auto     4688   Petrol         4.0
# 61187   S Class  2019  104590    Automatic     3671   Petrol         4.0
# 61292   S Class  2018  104400    Semi-Auto     3796   Petrol         4.0
# 66158   S Class  2019   81900    Automatic    21442   Petrol         4.0
# 59323   S Class  2018   79995    Semi-Auto     6623   Petrol         4.0
# 60417   S Class  2019   79980    Semi-Auto     5000   Petrol         4.0
# 62409   S Class  2016   79950    Semi-Auto    25317   Petrol         6.0
# 59541   S Class  2018   72995    Semi-Auto     9740   Petrol         4.0
# 63843   S Class  2017   67699    Semi-Auto    15400   Petrol         5.5
# 59666   S Class  2020   64980    Semi-Auto     3999   Diesel         3.0
#
#         manufacturer
# 59388  Mercedes-Benz
# 61187  Mercedes-Benz
# 61292  Mercedes-Benz
# 66158  Mercedes-Benz
# 59323  Mercedes-Benz
# 60417  Mercedes-Benz
# ...

# %% [markdown]
# It seems logical to me that a newer model is considerably smaller than previous models.

# %%
s_class = s_class.query("price < 65000")

# %%
s_class.sort_values(by = "price",ascending = False).head(10)
# Out:
#           model  year  price transmission  mileage fuelType  engineSize  \
# 59666   S Class  2020  64980    Semi-Auto     3999   Diesel         3.0
# 64210   S Class  2019  61899    Automatic     5260   Diesel         3.0
# 64702   S Class  2019  60849    Semi-Auto     6675   Diesel         3.0
# 58113   S Class  2019  59998    Semi-Auto    10500   Petrol         3.0
# 62871   S Class  2019  59949    Automatic     6468   Diesel         3.0
# 61326   S Class  2019  58990    Automatic     6501   Diesel         3.0
# 61692   S Class  2019  58700    Automatic     3767   Diesel         3.0
# 64253   S Class  2018  57899    Automatic     3728   Diesel         3.0
# 68206   S Class  2019  57890    Automatic     7125   Diesel         3.0
# 59840   S Class  2017  57752    Semi-Auto    12376   Petrol         4.7
#
#         manufacturer
# 59666  Mercedes-Benz
# 64210  Mercedes-Benz
# 64702  Mercedes-Benz
# 58113  Mercedes-Benz
# 62871  Mercedes-Benz
# 61326  Mercedes-Benz
# ...

# %% [markdown]
# We managed to successfully clean this particular model.

# %%
g_class.sort_values(by = "price",ascending = False).head(10)
# Out:
#           model  year   price transmission  mileage fuelType  engineSize  \
# 63023   G Class  2018  139995    Semi-Auto    13046   Petrol         4.0
# 57573   G Class  2019  139948    Automatic    12000   Petrol         4.0
# 62642   G Class  2018  135771    Semi-Auto    19000   Petrol         4.0
# 64113   G Class  2018  135124    Semi-Auto    18234   Petrol         4.0
# 61105   G Class  2019  102502    Semi-Auto     8691   Diesel         3.0
# 62447   G Class  2015   99850    Semi-Auto    10000   Petrol         5.5
# 57571   G Class  2016   73948    Automatic     4000   Petrol         4.0
# 63172   G Class  2017   71995    Automatic    38247   Petrol         5.5
# 67646   G Class  2018   64950    Automatic    13000   Diesel         3.0
# 57570   G Class  2016   61948    Automatic    16000   Petrol         4.0
#
#         manufacturer
# 63023  Mercedes-Benz
# 57573  Mercedes-Benz
# 62642  Mercedes-Benz
# 64113  Mercedes-Benz
# 61105  Mercedes-Benz
# 62447  Mercedes-Benz
# ...

# %% [markdown]
# For the G-Class model, a fairly similar case occurs.

# %%
g_class = g_class.query("price < 65000")

# %%
g_class.sort_values(by = "price",ascending = False)
# Out:
#           model  year  price transmission  mileage fuelType  engineSize  \
# 67646   G Class  2018  64950    Automatic    13000   Diesel         3.0
# 57570   G Class  2016  61948    Automatic    16000   Petrol         4.0
# 57704   G Class  2015  52995    Semi-Auto    34400   Diesel         3.0
# 67166   G Class  2013  45000    Automatic    52438   Diesel         3.0
# 68230   G Class  2012  44990    Automatic    43000   Diesel         3.0
#
#         manufacturer
# 67646  Mercedes-Benz
# 57570  Mercedes-Benz
# 57704  Mercedes-Benz
# 67166  Mercedes-Benz
# 68230  Mercedes-Benz

# %%
g_class
# Out:
#           model  year  price transmission  mileage fuelType  engineSize  \
# 57570   G Class  2016  61948    Automatic    16000   Petrol         4.0
# 57704   G Class  2015  52995    Semi-Auto    34400   Diesel         3.0
# 67166   G Class  2013  45000    Automatic    52438   Diesel         3.0
# 67646   G Class  2018  64950    Automatic    13000   Diesel         3.0
# 68230   G Class  2012  44990    Automatic    43000   Diesel         3.0
#
#         manufacturer
# 57570  Mercedes-Benz
# 57704  Mercedes-Benz
# 67166  Mercedes-Benz
# 67646  Mercedes-Benz
# 68230  Mercedes-Benz

# %% [markdown]
# We managed to remove the outliers for this model, but only very few observations remained, so we will not include them because they may bias the model.

# %%
others_models = mercedes.query("model != ' G Class' and model  != ' S Class'")

# %%
mercedes = pd.concat([others_models,s_class])

# %%
mercedes.price.describe()
# Out:
# count     11040.000000
# mean      23011.317210
# std        9155.165067
# min        8238.000000
# 25%       16950.000000
# 50%       20900.000000
# 75%       26980.000000
# max      105000.000000
# Name: price, dtype: float64

# %% [markdown]
# ### *Save Dataset Clear*

# %%
mercedes.to_csv('C:/Users/PC/Desktop/Car-Sales/data/mercedes_clear.csv',index = False)
