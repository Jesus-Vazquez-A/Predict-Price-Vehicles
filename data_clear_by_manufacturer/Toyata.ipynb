# %% [markdown]
# ## **Load Libraires**

# %%
import pandas as pd
from intervals import IntervalFit
from histogram import histogram
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
toyota = pd.read_csv('C:/Users/PC/Desktop/Car-Sales/data/cars_sales2.csv')
toyota = toyota.query("manufacturer == 'Toyota'")

# %%
toyota.model.unique()
# Out:
# array([' GT86', ' Corolla', ' RAV4', ' Yaris', ' Auris', ' Aygo', ' C-HR',
#        ' Prius', ' Avensis', ' Verso', ' Hilux', ' Land Cruiser',
#        ' Camry'], dtype=object)

# %%
toyota.price.describe()
# Out:
# count     6052.000000
# mean     12239.097323
# std       5825.268482
# min       2095.000000
# 25%       7999.750000
# 50%      10690.000000
# 75%      14788.000000
# max      54550.000000
# Name: price, dtype: float64

# %%
_ = histogram(toyota.price,"Price")

# %%
IntervalFit(toyota.price).Upper_Interval()
# Out:
# Interval range STD 1.5: 20976.0
# Interval range STD 2: 23889.0
# Interval range STD 2.5: 26801.0
# Interval range STD 3.0: 29713.0
# Interval range STD 3.5: 32626.0
# Interval range STD 4: 35538.0

# %%
toyota.query("price > 35000").sort_values(by = "price",ascending = False).head(10)
# Out:
#               model  year  price transmission  mileage fuelType  engineSize  \
# 6038   Land Cruiser  2020  54550    Automatic     4000   Diesel         2.8
# 6023   Land Cruiser  2020  52291    Semi-Auto     3104   Diesel         2.8
# 6013   Land Cruiser  2020  50995    Semi-Auto     3390   Diesel         2.8
# 6032   Land Cruiser  2020  50995    Automatic     3500   Diesel         2.8
# 6019   Land Cruiser  2019  50995    Semi-Auto     6254   Diesel         2.8
# 6041   Land Cruiser  2019  49995    Automatic     6836   Diesel         2.8
# 6022   Land Cruiser  2019  47795    Semi-Auto     8813   Diesel         2.8
# 6015   Land Cruiser  2019  45995    Semi-Auto     8967   Diesel         2.8
# 6035   Land Cruiser  2019  44995    Automatic     4512   Diesel         2.8
# 6040   Land Cruiser  2014  44990    Automatic    60000   Diesel         4.5
#
#      manufacturer
# 6038       Toyota
# 6023       Toyota
# 6013       Toyota
# 6032       Toyota
# 6019       Toyota
# ...

# %% [markdown]
# I eliminate the model with the highest price, since the second model has better specifications and a more expensive transmission.

# %%
toyota = toyota.query("price < 53000")

# %%
toyota.sort_values(by = "price",ascending = False).head(10)
# Out:
#               model  year  price transmission  mileage fuelType  engineSize  \
# 6023   Land Cruiser  2020  52291    Semi-Auto     3104   Diesel         2.8
# 6019   Land Cruiser  2019  50995    Semi-Auto     6254   Diesel         2.8
# 6032   Land Cruiser  2020  50995    Automatic     3500   Diesel         2.8
# 6013   Land Cruiser  2020  50995    Semi-Auto     3390   Diesel         2.8
# 6041   Land Cruiser  2019  49995    Automatic     6836   Diesel         2.8
# 6022   Land Cruiser  2019  47795    Semi-Auto     8813   Diesel         2.8
# 6015   Land Cruiser  2019  45995    Semi-Auto     8967   Diesel         2.8
# 6035   Land Cruiser  2019  44995    Automatic     4512   Diesel         2.8
# 6040   Land Cruiser  2014  44990    Automatic    60000   Diesel         4.5
# 6026   Land Cruiser  2019  44935    Semi-Auto    15200   Diesel         2.8
#
#      manufacturer
# 6023       Toyota
# 6019       Toyota
# 6032       Toyota
# 6013       Toyota
# 6041       Toyota
# ...

# %% [markdown]
# There is a Land Cruiser model corresponding to the year 2014 that has a higher price than some more recent models.

# %%
toyota = toyota.query("price != 44990")

# %%
toyota.sort_values(by = "price",ascending = False).head(10)
# Out:
#               model  year  price transmission  mileage fuelType  engineSize  \
# 6023   Land Cruiser  2020  52291    Semi-Auto     3104   Diesel         2.8
# 6019   Land Cruiser  2019  50995    Semi-Auto     6254   Diesel         2.8
# 6032   Land Cruiser  2020  50995    Automatic     3500   Diesel         2.8
# 6013   Land Cruiser  2020  50995    Semi-Auto     3390   Diesel         2.8
# 6041   Land Cruiser  2019  49995    Automatic     6836   Diesel         2.8
# 6022   Land Cruiser  2019  47795    Semi-Auto     8813   Diesel         2.8
# 6015   Land Cruiser  2019  45995    Semi-Auto     8967   Diesel         2.8
# 6035   Land Cruiser  2019  44995    Automatic     4512   Diesel         2.8
# 6026   Land Cruiser  2019  44935    Semi-Auto    15200   Diesel         2.8
# 6011   Land Cruiser  2019  42995    Semi-Auto    16634   Diesel         2.8
#
#      manufacturer
# 6023       Toyota
# 6019       Toyota
# 6032       Toyota
# 6013       Toyota
# 6041       Toyota
# ...

# %% [markdown]
# ### *Save Dataset Clear*

# %%
toyota.to_csv('C:/Users/PC/Desktop/Car-Sales/data/toyota_clear.csv',index = False)
