# %% [markdown]
# ## **Load Libraires**

# %%
import pandas as pd
from intervals import IntervalFit
from histogram import histogram
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
audi = pd.read_csv('C:/Users/PC/Desktop/Car-Sales/data/cars_sales2.csv')
audi = audi.query("manufacturer == 'Audi'")

# %%
audi.model.unique()
# Out:
# array([' A1', ' A6', ' A4', ' A3', ' Q3', ' Q5', ' A5', ' Q2', ' A7',
#        ' RS6', ' Q7', ' A8', ' TT', ' Q8', ' RS4', ' RS5', ' RS3', ' R8',
#        'A3', ' SQ5', ' S3'], dtype=object)

# %%
audi.price.describe()
# Out:
# count      9174.000000
# mean      21692.926422
# std       10724.664380
# min        2876.000000
# 25%       14729.250000
# 50%       19300.000000
# 75%       25990.000000
# max      129000.000000
# Name: price, dtype: float64

# %%
_ = histogram(audi.price,"Price")

# %%
IntervalFit(audi.price).Lower_Interval()
# Out:
# Interval range STD 1.5: 5607.0
# Interval range STD 2: 245.0
# Interval range STD 2.5: -5117.0
# Interval range STD 3.0: -10479.0
# Interval range STD 3.5: -15841.0
# Interval range STD 4: -21203.0

# %% [markdown]
# I find it convincing to use a lower range of £ 5,600, as car manufacturer Mercedez Benz is not known for its low prices.

# %%
audi = audi.query("price > 5600")

# %%
IntervalFit(audi.price).Upper_Interval()
# Out:
# Interval range STD 1.5: 37794.0
# Interval range STD 2: 43142.0
# Interval range STD 2.5: 48490.0
# Interval range STD 3.0: 53838.0
# Interval range STD 3.5: 59187.0
# Interval range STD 4: 64535.0

# %%
audi.sort_values(by = "price",ascending = False).head(10)
# Out:
#       model  year   price transmission  mileage fuelType  engineSize  \
# 40945    R8  2019  129000    Semi-Auto     4000   Petrol         5.2
# 48514    R8  2019  125000    Automatic    13663   Petrol         5.2
# 45907    R8  2019  119995    Semi-Auto     7800   Petrol         5.2
# 43723    R8  2019  117990    Automatic    11936   Petrol         5.2
# 43010    R8  2019  112990    Automatic     8175   Petrol         5.2
# 43899    R8  2019  109990    Automatic     6954   Petrol         5.2
# 42800   RS6  2020   97500    Semi-Auto     3220   Petrol         4.0
# 46934    R8  2018   95950    Automatic     5044   Petrol         5.2
# 44195    R8  2018   94990    Automatic     3562   Petrol         5.2
# 43407    R8  2018   93950    Semi-Auto     3800   Petrol         5.2
#
#       manufacturer
# 40945         Audi
# 48514         Audi
# 45907         Audi
# 43723         Audi
# 43010         Audi
# 43899         Audi
# 42800         Audi
# 46934         Audi
# 44195         Audi
# ...

# %% [markdown]
# The £64K+ price range is dominated by the Audi R8, which makes a lot of sense as it is a high-end car,
# in addition, the most expensive model has a fairly low mileage and a semi-automatic transmission.
#
# However, the second case has higher mileage and a cheaper transmission than a semi-automatic gearbox.

# %%
audi = audi.query("price != 125000")

# %%
audi.sort_values(by = "price",ascending = False).head(10)
# Out:
#       model  year   price transmission  mileage fuelType  engineSize  \
# 40945    R8  2019  129000    Semi-Auto     4000   Petrol         5.2
# 45907    R8  2019  119995    Semi-Auto     7800   Petrol         5.2
# 43723    R8  2019  117990    Automatic    11936   Petrol         5.2
# 43010    R8  2019  112990    Automatic     8175   Petrol         5.2
# 43899    R8  2019  109990    Automatic     6954   Petrol         5.2
# 42800   RS6  2020   97500    Semi-Auto     3220   Petrol         4.0
# 46934    R8  2018   95950    Automatic     5044   Petrol         5.2
# 44195    R8  2018   94990    Automatic     3562   Petrol         5.2
# 43407    R8  2018   93950    Semi-Auto     3800   Petrol         5.2
# 44054    Q7  2020   89990    Semi-Auto     5000   Diesel         4.0
#
#       manufacturer
# 40945         Audi
# 45907         Audi
# 43723         Audi
# 43010         Audi
# 43899         Audi
# 42800         Audi
# 46934         Audi
# 44195         Audi
# 43407         Audi
# ...

# %%
audi = audi.query("price != 117990")

# %%
audi.sort_values(by = "price",ascending = False).head(10)
# Out:
#       model  year   price transmission  mileage fuelType  engineSize  \
# 40945    R8  2019  129000    Semi-Auto     4000   Petrol         5.2
# 45907    R8  2019  119995    Semi-Auto     7800   Petrol         5.2
# 43010    R8  2019  112990    Automatic     8175   Petrol         5.2
# 43899    R8  2019  109990    Automatic     6954   Petrol         5.2
# 42800   RS6  2020   97500    Semi-Auto     3220   Petrol         4.0
# 46934    R8  2018   95950    Automatic     5044   Petrol         5.2
# 44195    R8  2018   94990    Automatic     3562   Petrol         5.2
# 43407    R8  2018   93950    Semi-Auto     3800   Petrol         5.2
# 44054    Q7  2020   89990    Semi-Auto     5000   Diesel         4.0
# 42502    Q8  2019   89750    Automatic     5800   Diesel         4.0
#
#       manufacturer
# 40945         Audi
# 45907         Audi
# 43010         Audi
# 43899         Audi
# 42800         Audi
# 46934         Audi
# 44195         Audi
# 43407         Audi
# 44054         Audi
# ...

# %%
audi.query("model == ' RS6'").sort_values(by = 'price',ascending = False).head(10)
# Out:
#       model  year  price transmission  mileage fuelType  engineSize  \
# 42800   RS6  2020  97500    Semi-Auto     3220   Petrol         4.0
# 48516   RS6  2018  70000    Automatic     3840   Petrol         4.0
# 46085   RS6  2017  61700    Automatic    22558   Petrol         4.0
# 44064   RS6  2017  61490    Automatic    18881   Petrol         4.0
# 48035   RS6  2017  59900    Automatic    17283   Petrol         4.0
# 39867   RS6  2017  57995    Semi-Auto    34926   Petrol         4.0
# 45778   RS6  2017  56990    Semi-Auto    20814   Petrol         4.0
# 44425   RS6  2017  56950    Semi-Auto    13051   Petrol         4.0
# 40592   RS6  2017  54998    Semi-Auto     8546   Petrol         4.0
# 41515   RS6  2017  54995    Automatic    15500   Petrol         4.0
#
#       manufacturer
# 42800         Audi
# 48516         Audi
# 46085         Audi
# 44064         Audi
# 48035         Audi
# 39867         Audi
# 45778         Audi
# 44425         Audi
# 40592         Audi
# ...

# %% [markdown]
# The price of the higher RS6 model can be explained, due to the model being more recent as well as having a semi-automatic transmission which is more expensive.

# %%
audi = audi.query("price != 54998")

# %%
audi.query("model == ' RS6'").sort_values(by = 'price',ascending = False).head(10)
# Out:
#       model  year  price transmission  mileage fuelType  engineSize  \
# 42800   RS6  2020  97500    Semi-Auto     3220   Petrol         4.0
# 48516   RS6  2018  70000    Automatic     3840   Petrol         4.0
# 46085   RS6  2017  61700    Automatic    22558   Petrol         4.0
# 44064   RS6  2017  61490    Automatic    18881   Petrol         4.0
# 48035   RS6  2017  59900    Automatic    17283   Petrol         4.0
# 39867   RS6  2017  57995    Semi-Auto    34926   Petrol         4.0
# 45778   RS6  2017  56990    Semi-Auto    20814   Petrol         4.0
# 44425   RS6  2017  56950    Semi-Auto    13051   Petrol         4.0
# 41515   RS6  2017  54995    Automatic    15500   Petrol         4.0
# 43770   RS6  2017  54990    Automatic    39300   Petrol         4.0
#
#       manufacturer
# 42800         Audi
# 48516         Audi
# 46085         Audi
# 44064         Audi
# 48035         Audi
# 39867         Audi
# 45778         Audi
# 44425         Audi
# 41515         Audi
# ...

# %% [markdown]
# ### *Save Dataset Clear*

# %%
audi.to_csv('C:/Users/PC/Desktop/Car-Sales/data/audi_clear.csv',index = False)
